# %% [markdown]
# # Part 4.3: HyperParameter tuning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold, cross_val_score
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_validate

# %%
import mlflow
import mlflowFunction as m
mlflow.set_tracking_uri("http://127.0.0.1:5000")
print("Tracking URI:", mlflow.get_tracking_uri())
mlflow.set_experiment("Model Development")
mlflow.utils.logging_utils.disable_logging()
# Out:
# Tracking URI: http://127.0.0.1:5000

# %%
train_df = pd.read_parquet('C:\\Users\\Hzaab\\Desktop\\MLSD project\\data\\preprocessed\\train.parquet', engine='fastparquet')
TARGET_COL = 'fake'

X = train_df.drop(columns=[TARGET_COL])
y = train_df[TARGET_COL]

cv = KFold(n_splits=5, shuffle=True, random_state=10)

from sklearn.model_selection import cross_validate

# %%
# svm
print('\n--- SVM ---')
svm_clf = SVC(random_state=10, class_weight='balanced')
scores=m.evaluate_model(X, y, "SVM_weighted", svm_clf, preprocess_fn=m.apply_no_sampling)
m.log_model_run("SVM_weighted", svm_clf, scores, X, y)
# Out:
# --- SVM ---
# SVM_weighted
# Accuracy: 0.9605, F1: 0.9039, Recall: 0.9300, Precision: 0.8794
# 🏃 View run SVM_weighted at: http://127.0.0.1:5000/#/experiments/2/runs/1637d4a357b346848e37395376f8ee07
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %% [markdown]
# senstive models:

# %%
# svm
print('\n--- SVM ---')
svm_clf = SVC(random_state=10, class_weight='balanced')
scores=m.evaluate_model(X, y, "SVM_weighted_oversampled", svm_clf, preprocess_fn=m.apply_random_oversample)
m.log_model_run("SVM_weighted_oversampled", svm_clf, scores, X, y)
# Out:
# --- SVM ---
# SVM_weighted_oversampled
# Accuracy: 0.9600, F1: 0.9030, Recall: 0.9300, Precision: 0.8783
# 🏃 View run SVM_weighted_oversampled at: http://127.0.0.1:5000/#/experiments/2/runs/96e02c3b0b264e7eb888829b65c1a118
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
# svm
print('\n--- SVM ---')
svm_clf = SVC(random_state=10)
scores=m.evaluate_model(X, y, "SVM_oversampled", svm_clf, preprocess_fn=m.apply_random_oversample)
m.log_model_run("SVM_oversampled", svm_clf, scores, X, y)
# Out:
# --- SVM ---
# SVM_oversampled
# Accuracy: 0.9600, F1: 0.9030, Recall: 0.9300, Precision: 0.8783
# 🏃 View run SVM_oversampled at: http://127.0.0.1:5000/#/experiments/2/runs/2b4be1c306b84307abd68bd31fc9424f
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
# K-Nearest Neighbors
print('\n--- K-Nearest Neighbors ---')
knn_clf = KNeighborsClassifier()
scores=m.evaluate_model(X, y, "K-Nearest Neighbors_oversampled", knn_clf, preprocess_fn=m.apply_random_oversample)
m.log_model_run("K-Nearest Neighbors_oversampled", knn_clf, scores, X, y)
# Out:
# --- K-Nearest Neighbors ---
# K-Nearest Neighbors_oversampled
# Accuracy: 0.9550, F1: 0.8923, Recall: 0.9350, Precision: 0.8542
# 🏃 View run K-Nearest Neighbors_oversampled at: http://127.0.0.1:5000/#/experiments/2/runs/027ec760b2dd4af6ae7ef98e03cd6886
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
# svm
print('\n--- SVM ---')
svm_clf = SVC(random_state=10, class_weight='balanced')
scores=m.evaluate_model(X, y, "SVM_weighted_smote", svm_clf, preprocess_fn=m.apply_smote)
m.log_model_run("SVM_weighted_smote", svm_clf, scores, X, y)
# Out:
# --- SVM ---
# SVM_weighted_smote
# Accuracy: 0.9610, F1: 0.9054, Recall: 0.9325, Precision: 0.8809
# 🏃 View run SVM_weighted_smote at: http://127.0.0.1:5000/#/experiments/2/runs/c491a746ae934e07b2a7dbf813106c82
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2

# %%
# K-Nearest Neighbors
print('\n--- K-Nearest Neighbors ---')
knn_clf = KNeighborsClassifier()
scores=m.evaluate_model(X, y, "K-Nearest Neighbors_smote", knn_clf, preprocess_fn=m.apply_smote)
m.log_model_run("K-Nearest Neighbors_smote", knn_clf, scores, X, y)
# Out:
# --- K-Nearest Neighbors ---
# K-Nearest Neighbors_smote
# Accuracy: 0.9610, F1: 0.9057, Recall: 0.9375, Precision: 0.8767
# 🏃 View run K-Nearest Neighbors_smote at: http://127.0.0.1:5000/#/experiments/2/runs/84db14a3f5b44b999cd1f5fd4e55d087
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/2
